# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3],[4,1,6])
plt.show()

# %%
x=[1,2,13]
y=[4,1,6]
x2=[9,8,3]
y2=[3,0,6]

plt.xlabel("along x")
plt.ylabel("along y")
plt.plot(x,y,label='First Line')
plt.plot(x2,y2,label='Second Line')
plt.title("Tutorial\nCheck it out")
plt.legend()
plt.show()

# %%
#Bar charts and Histograms

# %%
x=[1,2,7,4]
y=[4,1,3,7]
x2=[9,8,3]
y2=[3,0,6]
plt.bar(x2,y2,label='Bar Chart2')


plt.xlabel(" x")
plt.ylabel("y")
plt.bar(x,y,label='Bar Chart1',color='k')
plt.title("Tutorial\nCheck it out")
plt.legend()
plt.show()

# %%
population_ages=[10,23,34,24,24,53,63,25,64,74,34,23,1,23,4,34,53,26,13,34,24,23,32,53,53,6] 
ids=[i for i in range(len(population_ages))]

# %%
#histogram must have something called as bins for understanding
bins=[0,10,20,30,40,50,60,70]
plt.hist(population_ages,bins,histtype='bar')
# Out:
# (array([3., 1., 8., 5., 0., 4., 2.]),
#  array([ 0, 10, 20, 30, 40, 50, 60, 70]),
#  <BarContainer object of 7 artists>)

# %%
#stackplot
days=[1,2,3,4,5]
eating=[10,23,34,24,24]
sleeping=[53,63,25,64,74]
working=[34,23,1,4,34]
playing=[53,26,13,34,24]
plt.stackplot(days,eating,sleeping,working,playing)

# %%
#loading the text data

# %%
file=open('C:/Users/kushal/Desktop/MS_UTD/Tech_Req/initial_reqs.txt','r')

# %%
file.read()
# Out:
# '1.Machine Learning\n2.Applied NLP\n3.Big Data\n4.Modelling with R\n5.Data Visualization{1.SAP Lumira 2.Tableau 3.D3 4.Excel Preview 5.MS Excel}\n6.SQL'

# %%
file.close()

# %%
with open('C:/Users/kushal/Desktop/MS_UTD/Tech_Req/initial_reqs.txt','r') as file:
    print(file.readline())
    print(file.readline())
# Out:
# 1.Machine Learning
#
# 2.Applied NLP

# %%
import numpy as np
spam_data=np.loadtxt('C:/Users/kushal/Documents/Book2.csv',dtype=float,delimiter=',')

# %%
spam_data
# Out:
# array([12., 23., 23., 34., 34., 56.])

# %%
np.genfromtxt('C:/Users/kushal/Desktop/MS_UTD/Tech_Req/initial_reqs.txt',dtype=None,delimiter=',',skip_header=0)
# Out:
# <ipython-input-39-f714a2357f8e>:1: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   np.genfromtxt('C:/Users/kushal/Desktop/MS_UTD/Tech_Req/initial_reqs.txt',dtype=None,delimiter=',',skip_header=0)
# array([b'1.Machine Learning', b'2.Applied NLP', b'3.Big Data',
#        b'4.Modelling with R',
#        b'5.Data Visualization{1.SAP Lumira 2.Tableau 3.D3 4.Excel Preview 5.MS Excel}',
#        b'6.SQL'], dtype='|S76')

# %%
#formatting the line in using matplotlib is easy,given in the documentation

# %%
import matplotlib.pyplot as plt
days=[1,2,3,4,5,6,7]
max_t=[34,45,23,45,45,2,3]
min_t=[12,23,4,22,34,54,23]
avg_t=[42,7,67,45,78,54,43]

plt.plot(days,max_t)
plt.plot(days,min_t)
plt.plot(days,avg_t,label='Avg')
plt.xlabel('Days')
plt.ylabel('Temperature')
plt.title('Weather')
plt.legend(loc='best',shadow=True)

# %%
a=['h','d','e']
b=np.arange(len(a))
print(b)
# Out:
# [0 1 2]

# %%
print(type(b))
# Out:
# <class 'numpy.ndarray'>

# %%
b
# Out:
# array([0, 1, 2])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
company=['Google','Amazon','MSFT','FB']
revenue=[90,135,89,27]
profit=[40,2,34,12]

# %%
xpos=np.arange(len(company))
xpos
# Out:
# array([0, 1, 2, 3])

# %%
plt.xticks(xpos,company)
plt.ylabel('Revenue(BLN)')
plt.title("US Tech Stocks")
plt.bar(xpos-0.2,revenue,width=0.4,label='Revenue')
plt.bar(xpos+0.2,profit,width=0.4,label='Profit')
plt.legend()

# %%
plt.yticks(xpos,company)
plt.ylabel('Revenue(BLN)')
plt.title("US Tech Stocks")
plt.barh(xpos-0.2,revenue,label='Revenue')
plt.barh(xpos+0.2,profit,label='Profit')
plt.legend()

# %%
company=['Google','Amazon','MSFT','FB']
revenue=[90,135,89,27]
plt.bar(company,revenue)#we can now diirectly use strings ,else we use xticks to replace with 0 1..array values
#orientation shows the horizontal or vertical manner
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
exp_vals=[1400,600,300,410,250]
exp_labels=['Home Rent','Food','Phone/Net Bill','Car','Other Utilities']
plt.pie(exp_vals,labels=exp_labels,radius=1,autopct='%0.1f%%')
plt.axis("equal")
plt.show()
plt.savefig('piechart.png')
